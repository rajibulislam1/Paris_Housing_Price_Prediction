# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('../data/ParisHousing.csv')
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
df.columns = df.columns.str.lower() # Lowercase for all columns
df.head()
# Out:
#    squaremeters  numberofrooms  hasyard  haspool  floors  citycode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    citypartrange  numprevowners  made  isnewbuilt  hasstormprotector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasstorageroom  hasguestroom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squaremeters       10000 non-null  int64
#  1   numberofrooms      10000 non-null  int64
#  2   hasyard            10000 non-null  int64
#  3   haspool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   citycode           10000 non-null  int64
#  6   citypartrange      10000 non-null  int64
#  7   numprevowners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isnewbuilt         10000 non-null  int64
#  10  hasstormprotector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasstorageroom     10000 non-null  int64
#  15  hasguestroom       10000 non-null  int64
# ...

# %% [markdown]
# ### Check column wise

# %% [markdown]
# #### squaremeters

# %%
df.squaremeters.value_counts()
# Out:
# squaremeters
# 79770    3
# 33749    3
# 96526    3
# 16006    3
# 68985    3
#         ..
# 21514    1
# 1726     1
# 44403    1
# 83841    1
# 59036    1
# Name: count, Length: 9483, dtype: int64

# %%
df.squaremeters.nunique()
# Out:
# 9483

# %%
# check missing values
df.squaremeters.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### numberofrooms

# %%
df.numberofrooms.value_counts()
# Out:
# numberofrooms
# 54    129
# 4     120
# 22    119
# 47    118
# 3     116
#      ...
# 6      85
# 31     84
# 34     84
# 40     82
# 9      75
# Name: count, Length: 100, dtype: int64

# %%
df.numberofrooms.nunique()
# Out:
# 100

# %%
# check missing values
df.numberofrooms.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### hasyard

# %%
df.hasyard.value_counts()
# Out:
# hasyard
# 1    5087
# 0    4913
# Name: count, dtype: int64

# %%
## check unique values
df.hasyard.nunique()
# Out:
# 2

# %%
# check missing values
df.hasyard.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### haspool

# %%
df.haspool.value_counts()
# Out:
# haspool
# 0    5032
# 1    4968
# Name: count, dtype: int64

# %%
df.haspool.nunique()
# Out:
# 2

# %%
### check missing values
df.haspool.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### floors

# %%
df.floors.value_counts()
# Out:
# floors
# 97     126
# 55     122
# 77     117
# 3      116
# 28     116
#       ...
# 15      83
# 74      83
# 48      83
# 100     82
# 92      75
# Name: count, Length: 100, dtype: int64

# %%
df.floors.nunique()
# Out:
# 100

# %%
df.floors.isnull().sum()
# Out:
# np.int64(0)

# %%
def column_summary_light(df):
    return pd.DataFrame({
        "missing_values": df.isna().sum(),
        "num_unique": df.nunique(),
        "dtype": df.dtypes
    }).reset_index().rename(columns={"index": "column"})

# %%
column_summary_light(df)
# Out:
#                column  missing_values  num_unique    dtype
# 0        squaremeters               0        9483    int64
# 1       numberofrooms               0         100    int64
# 2             hasyard               0           2    int64
# 3             haspool               0           2    int64
# 4              floors               0         100    int64
# 5            citycode               0        9509    int64
# 6       citypartrange               0          10    int64
# 7       numprevowners               0          10    int64
# 8                made               0          32    int64
# 9          isnewbuilt               0           2    int64
# 10  hasstormprotector               0           2    int64
# 11           basement               0        6352    int64
# 12              attic               0        6267    int64
# 13             garage               0         901    int64
# 14     hasstorageroom               0           2    int64
# ...

# %%
df.describe()
# Out:
#        squaremeters  numberofrooms       hasyard       haspool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            citycode  citypartrange  numprevowners         made    isnewbuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
df[df['floors'] >= 76]
# Out:
#       squaremeters  numberofrooms  hasyard  haspool  floors  citycode  \
# 1            80771             39        1        1      98     39381
# 4            70429             19        1        1      90     38045
# 6            58682             10        1        1      99      6450
# 10           23563             21        0        1      90     91058
# 13           13087             44        1        0      77     40475
# ...            ...            ...      ...      ...     ...       ...
# 9980         82333             28        0        0      78     23385
# 9983         87627             56        1        0      95     33850
# 9989         90996             81        1        1      80      1085
# 9992         33545             55        0        1      79      8288
# 9998         59036             70        0        0      96     55856
#
#       citypartrange  numprevowners  made  isnewbuilt  hasstormprotector  \
# ...

# %%
len(df)
# Out:
# 10000

# %% [markdown]
# ### Setting Up Validation Framework

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size= 0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
len(df_full_train), len(df_test), len(df_train), len(df_val)
# Out:
# (8000, 2000, 6000, 2000)

# %%
df_val
# Out:
#       squaremeters  numberofrooms  hasyard  haspool  floors  citycode  \
# 3188          8537             59        1        0      49     19292
# 8293         72381             93        0        1      20     32337
# 1710         77913              6        0        0      82     89070
# 7510         83776             21        1        1      33     64605
# 1461         83197             46        1        1      68     36740
# ...            ...            ...      ...      ...     ...       ...
# 2834         23184             56        1        1     100     70418
# 449          15542             19        0        0      27     48610
# 6686         16205             88        0        0      11     98132
# 3561         30291             10        0        0      24     14914
# 9595         14945             33        1        1       3     54997
#
#       citypartrange  numprevowners  made  isnewbuilt  hasstormprotector  \
# ...

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.price
y_val = df_val.price
y_test = df_test.price
